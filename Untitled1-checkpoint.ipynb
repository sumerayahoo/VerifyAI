# %%
import requests

url = "http://127.0.0.1:5000/predict"

data = {
    "news": "RBI keeps repo rate unchanged at 5.25%, announces forex measures to attract dollars"
}

response = requests.post(url, json=data)

print(response.status_code)
print(response.json())
# Out:
# 200
# {'prediction': 'Fake News', 'related_news': [{'source': 'BusinessLine', 'title': 'RBI keeps repo rate unchanged at 5.25%, announces forex measures to attract dollars', 'url': 'https://www.thehindubusinessline.com/multimedia/video/rbi-keeps-repo-rate-unchanged-at-525-announces-forex-measures-to-attract-dollars/article71064617.ece'}]}
